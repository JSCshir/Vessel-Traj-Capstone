# %%
import pandas as pd
from geographiclib.geodesic import Geodesic
import geopandas
from geographiclib.geodesic import Geodesic
import math
import folium
geod = Geodesic.WGS84 

data = 'obc_tanker_cargo.csv'
df = pd.read_csv(data)
df.shape
# Out:
# (131308, 23)

# %%
df['BEAM'] = df['DIM_PORT'] + df['DIM_STARBOARD']
df['LENGTH'] = df['DIM_BOW'] + df['DIM_STERN']
df = df[df['BEAM'] > 0]
df = df[df['LENGTH'] > 0]
df = df[df['DRAUGHT'] > 0]
df.shape
# Out:
# (127770, 25)

# %%
df = df[df['NAV_STATUS'] == 0]
df.shape
# Out:
# (125355, 25)

# %%
df = df[df['SPEED_KNOTS'] > 3]
df.shape
# Out:
# (124600, 25)

# %%
df['MMSI'].nunique()
# Out:
# 3522

# %%
df['PERIOD'] = pd.to_datetime(df['PERIOD'])
df['DATE'] = df['PERIOD'].dt.date
df['TIME'] = df['PERIOD'].dt.time
df['CHANNEL_SIDE'] = ['Northwestbound' if x > 200 else 'Southeastbound' for x in df['COG_DEG']]

# %%
df = df.sort_values(['MMSI', 'PERIOD'])
df['time_diff'] = (df.groupby('MMSI')['PERIOD'].diff().dt.total_seconds())

threshold = 3 * 3600
df['new_voyage'] = (df['time_diff'] > threshold)
df['voyage_id'] = (df.groupby('MMSI')['new_voyage'].cumsum()+1)
df
# Out:
#         MSG_TYPE       MMSI          NAME  IMO_NUMBER CALL_SIGN    LAT_AVG  \
# 116677         1  205042000         DELOS   9877767.0      ONKR  22.736758
# 116686         1  205042000         DELOS   9877767.0      ONKR  22.707576
# 116687         1  205042000         DELOS   9877767.0      ONKR  22.705818
# 116698         1  205042000         DELOS   9877767.0      ONKR  22.666790
# 116703         1  205042000         DELOS   9877767.0      ONKR  22.654898
# ...          ...        ...           ...         ...       ...        ...
# 102529         1  720202000  INTL VICTORY   8977766.0   CPA3027  23.360848
# 102530         1  720202000  INTL VICTORY   8977766.0   CPA3027  23.364144
# 102854         1  720202000  INTL VICTORY   8977766.0   CPA3027  22.251636
# 102859         1  720202000  INTL VICTORY   8977766.0   CPA3027  22.009253
# 102866         1  720202000  INTL VICTORY   8977766.0   CPA3027  21.971778
#
#           LON_AVG              PERIOD  SPEED_KNOTS  COG_DEG  ...  \
# 116677 -78.616947 2023-06-04 14:00:00         13.0    110.0  ...
# 116686 -78.536280 2023-06-04 14:20:00         13.1    111.2  ...
# 116687 -78.531350 2023-06-04 14:25:00         13.1    111.3  ...
# 116698 -78.419349 2023-06-04 14:55:00         13.3    110.4  ...
# 116703 -78.384704 2023-06-04 15:05:00         13.4    110.2  ...
# ...           ...                 ...          ...      ...  ...
# 102529 -78.953454 2024-10-28 21:30:00          7.0    342.5  ...
# 102530 -78.954727 2024-10-28 21:35:00          6.9    346.9  ...
# 102854 -77.465667 2024-11-15 21:30:00          6.3    130.8  ...
# 102859 -77.023147 2024-11-16 02:10:00          6.3    116.5  ...
# 102866 -76.946660 2024-11-16 02:55:00          6.6    119.0  ...
#
#         MMSI_COUNTRY_CD  RECEIVER  BEAM  LENGTH        DATE      TIME  \
# 116677               BE     rEV02    60     336  2023-06-04  14:00:00
# 116686               BE     rEV02    60     336  2023-06-04  14:20:00
# 116687               BE     rEV02    60     336  2023-06-04  14:25:00
# 116698               BE     rEV02    60     336  2023-06-04  14:55:00
# 116703               BE     rEV02    60     336  2023-06-04  15:05:00
# ...                 ...       ...   ...     ...         ...       ...
# 102529               BO       NaN    12      33  2024-10-28  21:30:00
# 102530               BO       NaN    12      33  2024-10-28  21:35:00
# 102854               BO       NaN    12      33  2024-11-15  21:30:00
# 102859               BO       NaN    12      33  2024-11-16  02:10:00
# 102866               BO       NaN    12      33  2024-11-16  02:55:00
#
#           CHANNEL_SIDE  time_diff  new_voyage  voyage_id
# 116677  Southeastbound        NaN       False          1
# 116686  Southeastbound     1200.0       False          1
# 116687  Southeastbound      300.0       False          1
# 116698  Southeastbound     1800.0       False          1
# 116703  Southeastbound      600.0       False          1
# ...                ...        ...         ...        ...
# 102529  Northwestbound    26100.0        True         25
# 102530  Northwestbound      300.0       False         25
# 102854  Southeastbound  1554900.0        True         26
# 102859  Southeastbound    16800.0        True         27
# 102866  Southeastbound     2700.0       False         27
#
# [124600 rows x 31 columns]

# %%
ping_counts = (df.groupby(['MMSI', 'voyage_id']).size().reset_index(name='num_pings'))
ping_counts.sort_values(['num_pings'])
# Out:
#             MMSI  voyage_id  num_pings
# 30     205681000         10          1
# 25     205681000          5          1
# 23     205681000          3          1
# 15992  720202000         24          1
# 9548   477162100          1          1
# ...          ...        ...        ...
# 13667  636020073          1        148
# 13145  636016672          1        151
# 12354  563758000          7        153
# 949    219466000          2        158
# 7896   353054000          4        167
#
# [15996 rows x 3 columns]

# %%
sus_vessel = df[df['MMSI']==353054000]
sus_vessel = sus_vessel[sus_vessel['voyage_id']==4]
sus_vessel
# Out:
#        MSG_TYPE       MMSI      NAME  IMO_NUMBER CALL_SIGN    LAT_AVG  \
# 49417         1  353054000  BALSA 94   9800855.0      H9TG  22.980534
# 49418         1  353054000  BALSA 94   9800855.0      H9TG  22.974169
# 49419         1  353054000  BALSA 94   9800855.0      H9TG  22.968548
# 49421         1  353054000  BALSA 94   9800855.0      H9TG  22.963040
# 49422         1  353054000  BALSA 94   9800855.0      H9TG  22.957961
# ...         ...        ...       ...         ...       ...        ...
# 50763         1  353054000  BALSA 94   9800855.0      H9TG  21.716168
# 50778         1  353054000  BALSA 94   9800855.0      H9TG  21.708614
# 50781         1  353054000  BALSA 94   9800855.0      H9TG  21.701391
# 50797         1  353054000  BALSA 94   9800855.0      H9TG  21.694136
# 50800         1  353054000  BALSA 94   9800855.0      H9TG  21.686934
#
#          LON_AVG              PERIOD  SPEED_KNOTS  COG_DEG  ...  \
# 49417 -79.336711 2024-02-24 00:05:00         11.3    110.9  ...
# 49418 -79.318125 2024-02-24 00:10:00         11.2    109.9  ...
# 49419 -79.301316 2024-02-24 00:15:00         11.3    110.4  ...
# 49421 -79.283819 2024-02-24 00:20:00         11.3    108.8  ...
# 49422 -79.267942 2024-02-24 00:25:00         11.3    109.5  ...
# ...          ...                 ...          ...      ...  ...
# 50763 -76.892965 2024-02-24 14:00:00         11.2    115.9  ...
# 50778 -76.876192 2024-02-24 14:05:00         11.1    116.1  ...
# 50781 -76.860013 2024-02-24 14:10:00         11.1    115.4  ...
# 50797 -76.843530 2024-02-24 14:15:00         11.0    115.3  ...
# 50800 -76.827478 2024-02-24 14:20:00         11.0    115.9  ...
#
#        MMSI_COUNTRY_CD     RECEIVER  BEAM  LENGTH        DATE      TIME  \
# 49417               PA  rORBCOMM999    19     106  2024-02-24  00:05:00
# 49418               PA  rORBCOMM999    19     106  2024-02-24  00:10:00
# 49419               PA  rORBCOMM999    19     106  2024-02-24  00:15:00
# 49421               PA  rORBCOMM999    19     106  2024-02-24  00:20:00
# 49422               PA  rORBCOMM999    19     106  2024-02-24  00:25:00
# ...                ...          ...   ...     ...         ...       ...
# 50763               PA  rORBCOMM999    19     106  2024-02-24  14:00:00
# 50778               PA  rORBCOMM999    19     106  2024-02-24  14:05:00
# 50781               PA  rORBCOMM999    19     106  2024-02-24  14:10:00
# 50797               PA  rORBCOMM999    19     106  2024-02-24  14:15:00
# 50800               PA  rORBCOMM999    19     106  2024-02-24  14:20:00
#
#          CHANNEL_SIDE  time_diff  new_voyage  voyage_id
# 49417  Southeastbound  7666800.0        True          4
# 49418  Southeastbound      300.0       False          4
# 49419  Southeastbound      300.0       False          4
# 49421  Southeastbound      300.0       False          4
# 49422  Southeastbound      300.0       False          4
# ...               ...        ...         ...        ...
# 50763  Southeastbound      300.0       False          4
# 50778  Southeastbound      300.0       False          4
# 50781  Southeastbound      300.0       False          4
# 50797  Southeastbound      300.0       False          4
# 50800  Southeastbound      300.0       False          4
#
# [167 rows x 31 columns]

# %%
sus_vessel['time_diff'].describe()
# Out:
# count    1.670000e+02
# mean     4.621617e+04
# std      5.932509e+05
# min      3.000000e+02
# 25%      3.000000e+02
# 50%      3.000000e+02
# 75%      3.000000e+02
# max      7.666800e+06
# Name: time_diff, dtype: float64

# %%
data = pd.read_csv('obc_boundaries.csv')
from shapely.geometry import Point
from shapely.geometry import Polygon
data = data[data['Line']!='Middle']
data['geometry'] = data.apply(lambda x: (float(x.Long), float(x.Lat)), axis=1)

channel_coords = list(data['geometry'])
channel_coords_reorder = [channel_coords[0], channel_coords[1], channel_coords[2], channel_coords[3], channel_coords[-1], channel_coords[-2], channel_coords[-3], channel_coords[-4]]
channel_polygon = Polygon(channel_coords_reorder)
geo_df_channel = geopandas.GeoDataFrame(geometry=[channel_polygon], crs='EPSG:4326')

# %%
geo_df_sus_vessel = geopandas.GeoDataFrame(sus_vessel, geometry=geopandas.points_from_xy(sus_vessel['LON_AVG'], sus_vessel['LAT_AVG']), crs='EPSG:4326')

# %%
def where_is_vessel(LAT_AVG, LON_AVG, BOOL):
    if BOOL == True:
        answer = 'in channel'
    elif LON_AVG < -78.72296667:
        answer = 'west'
    elif LON_AVG > -77.49385:
        answer = 'east'
    elif LAT_AVG > 22.84101667:
        answer = 'north'
    elif LAT_AVG < 22.12445:
        answer = 'south'
    else:
        answer = 'other'
    return answer

# %%
geo_df_sus_vessel['in_channel'] = geo_df_sus_vessel.within(channel_polygon)
geo_df_sus_vessel['location'] = geo_df_sus_vessel.apply(lambda x: where_is_vessel(x.LAT_AVG, x.LON_AVG, x.in_channel), axis=1)
geo_df_sus_vessel.head()
# Out:
#        MSG_TYPE       MMSI      NAME  IMO_NUMBER CALL_SIGN    LAT_AVG  \
# 49417         1  353054000  BALSA 94   9800855.0      H9TG  22.980534
# 49418         1  353054000  BALSA 94   9800855.0      H9TG  22.974169
# 49419         1  353054000  BALSA 94   9800855.0      H9TG  22.968548
# 49421         1  353054000  BALSA 94   9800855.0      H9TG  22.963040
# 49422         1  353054000  BALSA 94   9800855.0      H9TG  22.957961
#
#          LON_AVG              PERIOD  SPEED_KNOTS  COG_DEG  ...  LENGTH  \
# 49417 -79.336711 2024-02-24 00:05:00         11.3    110.9  ...     106
# 49418 -79.318125 2024-02-24 00:10:00         11.2    109.9  ...     106
# 49419 -79.301316 2024-02-24 00:15:00         11.3    110.4  ...     106
# 49421 -79.283819 2024-02-24 00:20:00         11.3    108.8  ...     106
# 49422 -79.267942 2024-02-24 00:25:00         11.3    109.5  ...     106
#
#              DATE      TIME    CHANNEL_SIDE  time_diff  new_voyage  voyage_id  \
# 49417  2024-02-24  00:05:00  Southeastbound  7666800.0        True          4
# 49418  2024-02-24  00:10:00  Southeastbound      300.0       False          4
# 49419  2024-02-24  00:15:00  Southeastbound      300.0       False          4
# 49421  2024-02-24  00:20:00  Southeastbound      300.0       False          4
# 49422  2024-02-24  00:25:00  Southeastbound      300.0       False          4
#
#                          geometry  in_channel  location
# 49417  POINT (-79.33671 22.98053)       False      west
# 49418  POINT (-79.31812 22.97417)       False      west
# 49419  POINT (-79.30132 22.96855)       False      west
# 49421  POINT (-79.28382 22.96304)       False      west
# 49422  POINT (-79.26794 22.95796)       False      west
#
# [5 rows x 34 columns]

# %%
df_unique_full = df.drop_duplicates(subset='MMSI').copy()
df_unique_full['first_three'] = (df_unique_full['MMSI'].astype(str).str[:3].astype(int))

# %%
df_unique_full.sort_values(['first_three'])
print(df_unique_full['first_three'].value_counts())
# Out:
# first_three
# 538    685
# 636    596
# 477    198
# 563    191
# 352    136
#       ...
# 622      1
# 642      1
# 632      1
# 626      1
# 668      1
# Name: count, Length: 105, dtype: int64

# %%
geo_df_sus_vessel_clean = geo_df_sus_vessel['geometry']
geo_df_sus_vessel['in_channel'].value_counts()
# Out:
# in_channel
# False    84
# True     83
# Name: count, dtype: int64

# %%
my_map = folium.Map(location=[22.5, -77.8], zoom_start=11)
folium.GeoJson(geo_df_channel).add_to(my_map)
folium.GeoJson(geo_df_sus_vessel_clean).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7028fcd7f32e7de662cf497409ab3e9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7028fcd7f32e7de662cf497409ab3e9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7028fcd7f32e7de662cf497409ab3e9c = L.map(
#                 &quot;map_7028fcd7f32e7de662cf497409ab3e9c&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b2f8f47a13515269d7b9a63c296b686 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b2f8f47a13515269d7b9a63c296b686.addTo(map_7028fcd7f32e7de662cf497409ab3e9c);
#
#
#
#         function geo_json_ba1d9998a9d1089b263b3713eb958fe4_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_ba1d9998a9d1089b263b3713eb958fe4 = L.geoJson(null, {
#                 onEachFeature: geo_json_ba1d9998a9d1089b263b3713eb958fe4_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_ba1d9998a9d1089b263b3713eb958fe4_add (data) {
#             geo_json_ba1d9998a9d1089b263b3713eb958fe4
#                 .addData(data);
#         }
#             geo_json_ba1d9998a9d1089b263b3713eb958fe4_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_ba1d9998a9d1089b263b3713eb958fe4.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_ba1d9998a9d1089b263b3713eb958fe4.addTo(map_7028fcd7f32e7de662cf497409ab3e9c);
#
#
#
#         function geo_json_4a98dd0a8c63752f18bd8f668345ae65_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_4a98dd0a8c63752f18bd8f668345ae65 = L.geoJson(null, {
#                 onEachFeature: geo_json_4a98dd0a8c63752f18bd8f668345ae65_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_4a98dd0a8c63752f18bd8f668345ae65_add (data) {
#             geo_json_4a98dd0a8c63752f18bd8f668345ae65
#                 .addData(data);
#         }
#             geo_json_4a98dd0a8c63752f18bd8f668345ae65_add({&quot;bbox&quot;: [-79.336711, 21.686934, -76.827478, 22.980534], &quot;features&quot;: [{&quot;bbox&quot;: [-79.336711, 22.980534, -79.336711, 22.980534], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.336711, 22.980534], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;49417&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-79.318125, 22.974169, -79.318125, 22.974169], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.318125, 22.974169], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;49418&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-79.301316, 22.968548, -79.301316, 22.968548], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.301316, 22.968548], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;49419&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-79.283819, 22.96304, -79.283819, 22.96304], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.283819, 22.96304], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;49421&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-79.267942, 22.957961, -79.267942, 22.957961], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.267942, 22.957961], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;49422&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-79.258269, 22.95475, -79.258269, 22.95475], &quot;geometry&quot;: {&quot;coordinates&quot;: [-79.258269, 22.95475], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;49425&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-79.238717, 22.948086, -79.238717, 22.948086], &quot;geometry&quot;: {&quo

# %%
geo_df_sus_vessel['SPEED_KNOTS'].hist()
# Out:
# <Axes: >

# %%
geo_df_vessels = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df['LON_AVG'], df['LAT_AVG']), crs='EPSG:4326')
geo_df_vessels['in_channel'] = geo_df_vessels.within(channel_polygon)
geo_df_vessels['location'] = geo_df_vessels.apply(lambda x: where_is_vessel(x.LAT_AVG, x.LON_AVG, x.in_channel), axis=1)
geo_df_vessels.head()
# Out:
#         MSG_TYPE       MMSI   NAME  IMO_NUMBER CALL_SIGN    LAT_AVG  \
# 116677         1  205042000  DELOS   9877767.0      ONKR  22.736758
# 116686         1  205042000  DELOS   9877767.0      ONKR  22.707576
# 116687         1  205042000  DELOS   9877767.0      ONKR  22.705818
# 116698         1  205042000  DELOS   9877767.0      ONKR  22.666790
# 116703         1  205042000  DELOS   9877767.0      ONKR  22.654898
#
#           LON_AVG              PERIOD  SPEED_KNOTS  COG_DEG  ...  LENGTH  \
# 116677 -78.616947 2023-06-04 14:00:00         13.0    110.0  ...     336
# 116686 -78.536280 2023-06-04 14:20:00         13.1    111.2  ...     336
# 116687 -78.531350 2023-06-04 14:25:00         13.1    111.3  ...     336
# 116698 -78.419349 2023-06-04 14:55:00         13.3    110.4  ...     336
# 116703 -78.384704 2023-06-04 15:05:00         13.4    110.2  ...     336
#
#               DATE      TIME    CHANNEL_SIDE  time_diff  new_voyage  \
# 116677  2023-06-04  14:00:00  Southeastbound        NaN       False
# 116686  2023-06-04  14:20:00  Southeastbound     1200.0       False
# 116687  2023-06-04  14:25:00  Southeastbound      300.0       False
# 116698  2023-06-04  14:55:00  Southeastbound     1800.0       False
# 116703  2023-06-04  15:05:00  Southeastbound      600.0       False
#
#         voyage_id                    geometry  in_channel    location
# 116677          1  POINT (-78.61695 22.73676)        True  in channel
# 116686          1  POINT (-78.53628 22.70758)        True  in channel
# 116687          1  POINT (-78.53135 22.70582)        True  in channel
# 116698          1  POINT (-78.41935 22.66679)        True  in channel
# 116703          1    POINT (-78.3847 22.6549)        True  in channel
#
# [5 rows x 34 columns]

# %%
geo_df_vessels['location'].value_counts()
# Out:
# location
# in channel    57930
# east          38432
# west          24277
# other          3056
# north           885
# south            20
# Name: count, dtype: int64

# %%
weird_vessels = geo_df_vessels[geo_df_vessels['location']!='in channel']
weird_vessels = weird_vessels[geo_df_vessels['location']!='east']
weird_vessels = weird_vessels[geo_df_vessels['location']!='west']
# Out:
# c:\Users\LAKwon\anaconda3\envs\capstone\Lib\site-packages\geopandas\geodataframe.py:1891: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)
# c:\Users\LAKwon\anaconda3\envs\capstone\Lib\site-packages\geopandas\geodataframe.py:1891: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   result = super().__getitem__(key)

# %%
weird_vessels.head()
weird_vessels_clean = weird_vessels[['geometry']]

# %%
m = folium.Map(location=[22.5, -77.8], zoom_start=11)
weird_vessels["PERIOD"] = weird_vessels['PERIOD'].astype(str)
folium.GeoJson(geo_df_channel).add_to(m)
folium.GeoJson(weird_vessels_clean).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97deec6cd7a6b416e5a6601518a82025 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97deec6cd7a6b416e5a6601518a82025&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97deec6cd7a6b416e5a6601518a82025 = L.map(
#                 &quot;map_97deec6cd7a6b416e5a6601518a82025&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d21aded98ca884fb02a299ce304e31f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d21aded98ca884fb02a299ce304e31f4.addTo(map_97deec6cd7a6b416e5a6601518a82025);
#
#
#
#         function geo_json_7ac078d4a9a52d3c7e0fba3e042119a3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7ac078d4a9a52d3c7e0fba3e042119a3 = L.geoJson(null, {
#                 onEachFeature: geo_json_7ac078d4a9a52d3c7e0fba3e042119a3_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_7ac078d4a9a52d3c7e0fba3e042119a3_add (data) {
#             geo_json_7ac078d4a9a52d3c7e0fba3e042119a3
#                 .addData(data);
#         }
#             geo_json_7ac078d4a9a52d3c7e0fba3e042119a3_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_7ac078d4a9a52d3c7e0fba3e042119a3.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_7ac078d4a9a52d3c7e0fba3e042119a3.addTo(map_97deec6cd7a6b416e5a6601518a82025);
#
#
#
#         function geo_json_5063a699948b4043c34249e1d04b9688_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5063a699948b4043c34249e1d04b9688 = L.geoJson(null, {
#                 onEachFeature: geo_json_5063a699948b4043c34249e1d04b9688_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_5063a699948b4043c34249e1d04b9688_add (data) {
#             geo_json_5063a699948b4043c34249e1d04b9688
#                 .addData(data);
#         }
#             geo_json_5063a699948b4043c34249e1d04b9688_add({&quot;bbox&quot;: [-78.722879, 22.0147, -77.494209, 23.397061], &quot;features&quot;: [{&quot;bbox&quot;: [-78.662527, 22.8593, -78.662527, 22.8593], &quot;geometry&quot;: {&quot;coordinates&quot;: [-78.662527, 22.8593], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;99475&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-77.768034, 22.338033, -77.768034, 22.338033], &quot;geometry&quot;: {&quot;coordinates&quot;: [-77.768034, 22.338033], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;44619&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-77.66495, 22.270783, -77.66495, 22.270783], &quot;geometry&quot;: {&quot;coordinates&quot;: [-77.66495, 22.270783], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;44621&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-77.653022, 22.262988, -77.653022, 22.262988], &quot;geometry&quot;: {&quot;coordinates&quot;: [-77.653022, 22.262988], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;44622&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-77.647117, 22.258733, -77.647117, 22.258733], &quot;geometry&quot;: {&quot;coordinates&quot;: [-77.647117, 22.258733], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;44625&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-77.584067, 22.201966, -77.584067, 22.201966], &quot;geometry&quot;: {&quot;coordinates&quot;: [-77.584067, 22.201966], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;44626&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-77.574052, 22.192951, -77.574052, 22.192951], &quot;geometry&quot;: {&quot;coo

# %%
df_unique = weird_vessels.drop_duplicates(subset='MMSI').copy()
df_unique['first_three'] = (df_unique['MMSI'].astype(str).str[:3].astype(int))

# %%
df_unique_full = df.drop_duplicates(subset='MMSI').copy()
df_unique_full['first_three'] = (df_unique_full['MMSI'].astype(str).str[:3].astype(int))

# %%
df_unique.shape
# Out:
# (107, 35)

# %%
x= df_unique_full['first_three'].value_counts()

# %%
x.to_frame()
x.sort_value('first_three')
x.to_csv('full_countries.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6564\4140519933.py in ?()
#       1 x.to_frame()
# ----> 2 x.sort_value('first_three')
#       3 x.to_csv('full_countries.csv')
#
# c:\Users\LAKwon\anaconda3\envs\capstone\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort_value'
