# %%
import pandas as pd
from geographiclib.geodesic import Geodesic
import math
import folium
geod = Geodesic.WGS84 
import datetime

# %%
data = 'obc_tanker_cargo.csv'
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    MSG_TYPE       MMSI             NAME  IMO_NUMBER CALL_SIGN    LAT_AVG  \
# 0         1  323150000       LPG EMILIA   9242209.0      CLBS  22.779250
# 1         1  334976000            BELEN   9196230.0     HQZX5  23.218183
# 2         1  319103800  STOLT SINCERITY   9680085.0      ZGEY  22.423079
# 3         1  323150000       LPG EMILIA   9242209.0      CLBS  22.701027
# 4         1  334979000      SARA REGINA   9142655.0     HQZX8  21.862225
#
#      LON_AVG                   PERIOD  SPEED_KNOTS  COG_DEG  ...  \
# 0 -78.741867  2023-04-01 00:00:00.000         14.7    110.0  ...
# 1 -78.842584  2023-04-01 00:00:00.000         10.2    323.4  ...
# 2 -77.790762  2023-04-01 00:00:00.000         13.7    302.6  ...
# 3 -78.515972  2023-04-01 00:55:00.000         14.8    109.0  ...
# 4 -76.873167  2023-04-01 00:55:00.000         10.9    294.0  ...
#
#    SHIP_AND_CARGO_TYPE  DRAUGHT  DRAUGHT.1  DIM_BOW  DIM_STERN  DIM_PORT  \
# 0                   80      8.4        8.4      143         35        14
# 1                   70      3.6        3.6       80         10         5
# 2                   80     10.5       10.5      155         30        18
# 3                   80      8.4        8.4      143         35        14
# 4                   70      3.8        3.8       79         12         7
#
#    DIM_STARBOARD  DESTINATION  MMSI_COUNTRY_CD     RECEIVER
# 0             14   FOR ORDERS               CU          NaN
# 1              9        USMIA               HN          NaN
# 2             14        INKAK               KY  rORBCOMM000
# 3             14   FOR ORDERS               CU          NaN
# 4              7        USMIA               HN          NaN
#
# [5 rows x 23 columns]

# %%
df['LENGTH'] = df['DIM_STERN'] + df['DIM_BOW']
df['BEAM'] = df['DIM_PORT'] + df['DIM_STARBOARD']
df.shape
# Out:
# (131308, 25)

# %%
df.columns
# Out:
# Index(['MSG_TYPE', 'MMSI', 'NAME', 'IMO_NUMBER', 'CALL_SIGN', 'LAT_AVG',
#        'LON_AVG', 'PERIOD', 'SPEED_KNOTS', 'COG_DEG', 'HEADING_DEG',
#        'NAV_STATUS', 'NAV_SENSOR', 'SHIP_AND_CARGO_TYPE', 'DRAUGHT',
#        'DRAUGHT.1', 'DIM_BOW', 'DIM_STERN', 'DIM_PORT', 'DIM_STARBOARD',
#        'DESTINATION', 'MMSI_COUNTRY_CD', 'RECEIVER', 'LENGTH', 'BEAM'],
#       dtype='object')

# %%
df['PERIOD'] = pd.to_datetime(df['PERIOD'])
df['DATE'] = df['PERIOD'].dt.date
df['TIME'] = df['PERIOD'].dt.time

# %%
df['MMSI'].nunique()
# Out:
# 3633

# %%
cog_hist = df['COG_DEG'].hist(bins=20)

# %%
df['CHANNEL_SIDE'] = ['Northwestbound' if x > 200 else 'Southeastbound' for x in df['COG_DEG']]

# %%
voyage_stats = df[['MMSI', 'PERIOD', 'CHANNEL_SIDE', 'LAT_AVG', 'LON_AVG', 'DATE']].sort_values(['MMSI', 'PERIOD'])
voyage_stats['time_diff'] = (voyage_stats.groupby('MMSI')['PERIOD'].diff().dt.total_seconds())

threshold = 3 * 3600
voyage_stats['new_voyage'] = (voyage_stats['time_diff'] > threshold)
voyage_stats['voyage_id'] = (voyage_stats.groupby('MMSI')['new_voyage'].cumsum()+1)

# %%
voyage_stats['time_diff_min'] = voyage_stats['time_diff'] / 60
voyage_stats['time_diff_min'].describe()
# Out:
# count    1.276750e+05
# mean     4.850729e+03
# std      4.350510e+04
# min      5.000000e+00
# 25%      5.000000e+00
# 50%      1.000000e+01
# 75%      5.000000e+01
# max      1.344525e+06
# Name: time_diff_min, dtype: float64

# %%
voyage_stats['voyage_id'].describe()
# Out:
# count    131308.000000
# mean         19.722309
# std          35.541316
# min           1.000000
# 25%           1.000000
# 50%           4.000000
# 75%          19.000000
# max         254.000000
# Name: voyage_id, dtype: float64

# %%
ping_counts = (voyage_stats.groupby(['MMSI', 'voyage_id']).size().reset_index(name='num_pings'))
ping_counts['num_pings'].describe()
# Out:
# count    17042.000000
# mean         7.704964
# std         11.652718
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          9.000000
# max        167.000000
# Name: num_pings, dtype: float64

# %%
voyage_stats.boxplot(column='voyage_id')
# Out:
# <Axes: >

# %%
df['LENGTH'].hist(bins=30)
# Out:
# <Axes: >

# %%
df['BEAM'].hist(bins=30)
# Out:
# <Axes: >

# %%
df['DRAUGHT'].hist(bins=30)
# Out:
# <Axes: >

# %%
x=df.groupby('MMSI')['voyage_id']
x

# %%
pings_per_voyage = df.groupby('MMSI')['voyage_id'].value_counts()
pings_per_voyage
# Out:
# MMSI       voyage_id
# 205042000  0            16
# 205082000  1            12
#            0             4
# 205086000  1             7
#            0             6
#                         ..
# 720202000  43            1
#            49            1
#            52            1
#            55            1
#            57            1
# Name: count, Length: 17042, dtype: int64

# %%
voyage_counts.hist(bins=50)
# Out:
# <Axes: >

# %%
df['CHANNEL_SIDE'].value_counts()
# Out:
# CHANNEL_SIDE
# Southeastbound    79496
# Northwestbound    51812
# Name: count, dtype: int64

# %%
sog_hist = df['SPEED_KNOTS'].hist(bins=20)

# %%
sog_hist = df['SPEED_KNOTS'].hist(bins=20)

# %%
date_hist = df['DATE'].hist(bins=36)

# %%
df['NAV_STATUS'].value_counts()
# Out:
# NAV_STATUS
# 0.0     128769
# 8.0       1313
# 2.0        551
# 5.0        373
# 3.0        115
# 1.0         55
# 9.0         29
# 15.0        16
# 4.0         16
# 11.0        13
# Name: count, dtype: int64

# %%
df['SHIP_AND_CARGO_TYPE'].value_counts()
# Out:
# SHIP_AND_CARGO_TYPE
# 70    63595
# 80    27607
# 79    17685
# 71     6084
# 89     4510
# 74     3251
# 84     2152
# 81     1958
# 82     1469
# 72      636
# 83      523
# 77      494
# 75      424
# 85      398
# 73      172
# 78      170
# 76      113
# 88       66
# 87        1
# Name: count, dtype: int64

# %%
df_sailing = df[df['NAV_STATUS']==8]

# %%
df_sailing['MMSI'].nunique()
# Out:
# 45

# %%
m = folium.Map(location=[22.5, -77.8], zoom_start=11)

# %%
for i in range(len(df)):
    folium.Marker(
        location=[df.iloc[i]['LAT_AVG'], df.iloc[i]['LON_AVG']],
        popup=df.iloc[i]['MMSI']
    ).add_to(m)

# %% [markdown]
# Add channel boundaries to map

# %%
data = pd.read_csv('obc_boundaries.csv')
lats = list(data['Lat'])
longs = list(data['Long'])

all_coords = []
counter = 0
for i in range(3):
    coords = []
    for j in range(4):
        coords.append([lats[counter], longs[counter]])
        counter += 1
    all_coords.append(coords)

for i in range(3):
    trail_coordinates = all_coords[i]
    folium.PolyLine(locations = trail_coordinates, color="#FF0000", weight=2).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac = L.map(
#                 &quot;map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7558b3b43eb1b3cfc731c9a3ea3aea9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7558b3b43eb1b3cfc731c9a3ea3aea9e.addTo(map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac);
#
#
#             var poly_line_2e139e94ab9208dc384fb5f0a01fcd33 = L.polyline(
#                 [[22.84101667, -78.72296667], [22.62481667, -78.0874], [22.3528, -77.63613333], [22.18378333, -77.44235]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac);
#
#
#             var poly_line_759c84583d6d3a83ad5ea572978c8a9a = L.polyline(
#                 [[22.77695, -78.78395], [22.55308333, -78.13211667], [22.2885, -77.68085], [22.12445, -77.49385]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac);
#
#
#             var poly_line_06a9effd54c27d587198da5b1393ab00 = L.polyline(
#                 [[22.80836667, -78.75143333], [22.59083333, -78.11315], [22.32128333, -77.65916667], [22.15348333, -77.4681]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_dfdfa7fa8c1a0bd33b7d4d08dfdee5ac);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
box1 = [[22.84101667, -78.72296667],[22.55308333, -78.13211667]]
box2 = [[22.62481667, -78.0874], [22.2885, -77.68085]]
box3 = [[22.3528, -77.63613333], [22.12445, -77.49385]]
boxes = [box1, box2, box3]
for box in boxes:
    for i in range(2):
        folium.Marker(location=box[i]).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4b6b96987a6f2af0aa91ba3fef7bd8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4b6b96987a6f2af0aa91ba3fef7bd8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4b6b96987a6f2af0aa91ba3fef7bd8b = L.map(
#                 &quot;map_a4b6b96987a6f2af0aa91ba3fef7bd8b&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43995272a93d598cf3134c1f5796be80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43995272a93d598cf3134c1f5796be80.addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var poly_line_578504a0c9e66945c301b2bd1c27f68b = L.polyline(
#                 [[22.84101667, -78.72296667], [22.62481667, -78.0874], [22.3528, -77.63613333], [22.18378333, -77.44235]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var poly_line_7c266bd9aa9a73610059e431e6cc0450 = L.polyline(
#                 [[22.77695, -78.78395], [22.55308333, -78.13211667], [22.2885, -77.68085], [22.12445, -77.49385]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var poly_line_9bc9fa3314b930884a5717ad4bf73fa0 = L.polyline(
#                 [[22.80836667, -78.75143333], [22.59083333, -78.11315], [22.32128333, -77.65916667], [22.15348333, -77.4681]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             tile_layer_43995272a93d598cf3134c1f5796be80.addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var marker_9c96f43c2bc77581f1300a0ca253d84f = L.marker(
#                 [22.84101667, -78.72296667],
#                 {
# }
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var marker_cf53fea1f9149a9ad1e036dfe1035fff = L.marker(
#                 [22.55308333, -78.13211667],
#                 {
# }
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var marker_926967ad50c2bc5ea3617cc22c82fa11 = L.marker(
#                 [22.62481667, -78.0874],
#                 {
# }
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var marker_fbc4a5d268f78681fbe3adc639e11800 = L.marker(
#                 [22.2885, -77.68085],
#                 {
# }
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var marker_6fa182a23a221de2fbc38c8b804df9d3 = L.marker(
#                 [22.3528, -77.63613333],
#                 {
# }
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
#
#             var marker_fe61e817cf70679e6c281695a3e9f05a = L.marker(
#                 [22.12445, -77.49385],
#                 {
# }
#             ).addTo(map_a4b6b96987a6f2af0aa91ba3fef7bd8b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data.head(8)
# Out:
#    Index        Lat       Long   Line                     geometry
# 0      1  22.841017 -78.722967  North  (-78.72296667, 22.84101667)
# 1      2  22.624817 -78.087400  North      (-78.0874, 22.62481667)
# 2      3  22.352800 -77.636133  North      (-77.63613333, 22.3528)
# 3      4  22.183783 -77.442350  North     (-77.44235, 22.18378333)
# 4      1  22.776950 -78.783950  South        (-78.78395, 22.77695)
# 5      2  22.553083 -78.132117  South  (-78.13211667, 22.55308333)
# 6      3  22.288500 -77.680850  South         (-77.68085, 22.2885)
# 7      4  22.124450 -77.493850  South        (-77.49385, 22.12445)

# %%
from shapely.geometry import Point
from shapely.geometry import Polygon
data = data[data['Line']!='Middle']
data['geometry'] = data.apply(lambda x: (float(x.Long), float(x.Lat)), axis=1)

# %%
channel_coords = list(data['geometry'])
channel_coords_reorder = [channel_coords[0], channel_coords[1], channel_coords[2], channel_coords[3], channel_coords[-1], channel_coords[-2], channel_coords[-3], channel_coords[-4]]
channel_polygon = Polygon(channel_coords_reorder)
geo_df_channel = geopandas.GeoDataFrame(geometry=[channel_polygon], crs='EPSG:4326')

# %%
geo_df_vessels = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df['LON_AVG'], df['LAT_AVG']), crs='EPSG:4326')

# %%
def where_is_vessel(LAT_AVG, LON_AVG, BOOL):
    if BOOL == True:
        answer = 'in channel'
    elif LON_AVG < -78.72296667:
        answer = 'west'
    elif LON_AVG > -77.49385:
        answer = 'east'
    elif LAT_AVG > 22.84101667:
        answer = 'north'
    elif LAT_AVG < 22.12445:
        answer = 'south'
    return answer

# %%
geo_df_vessels['in_channel'] = geo_df_vessels.within(channel_polygon)
geo_df_vessels['location'] = geo_df_vessels.apply(lambda x: where_is_vessel(x.LAT_AVG, x.LON_AVG, x.in_channel), axis=1)
geo_df_vessels.head()

# %%
geo_df_vessels['in_channel'].value_counts()
# Out:
# in_channel
# False    71140
# True     60168
# Name: count, dtype: int64

# %%
df['box1'] = (df["LAT_AVG"] <= box1[0][0]) & (df["LAT_AVG"] >= box1[1][0]) & (df["LON_AVG"] >= box1[0][1]) & (df["LON_AVG"] <= box1[1][1])
df['box2'] = (df["LAT_AVG"] <= box2[0][0]) & (df["LAT_AVG"] >= box2[1][0]) & (df["LON_AVG"] >= box2[0][1]) & (df["LON_AVG"] <= box2[1][1])
df['box3'] = (df["LAT_AVG"] <= box3[0][0]) & (df["LAT_AVG"] >= box3[1][0]) & (df["LON_AVG"] >= box3[0][1]) & (df["LON_AVG"] <= box3[1][1])
df['out_of_channel'] = (df['box1'] == False) & (df['box2'] == False) & (df['box3']==False)
df['out_of_channel'].value_counts()
# Out:
# out_of_channel
# True     75315
# False    55993
# Name: count, dtype: int64
