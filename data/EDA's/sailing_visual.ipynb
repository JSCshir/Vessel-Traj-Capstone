# %%
import pandas as pd
from geographiclib.geodesic import Geodesic
import geopandas
import math
import folium
from shapely.geometry import Point
from shapely.geometry import Polygon
import numpy as np
import matplotlib.pyplot as plt
import random as rand
geod = Geodesic.WGS84

# %%
data = 'obc_sailing.csv'
df = pd.read_csv(data)

# %%
print(df.dtypes)
# Out:
# MSG_TYPE                 int64
# MMSI                     int64
# NAME                    object
# IMO_NUMBER             float64
# CALL_SIGN               object
# LAT_AVG                float64
# LON_AVG                float64
# PERIOD                  object
# SPEED_KNOTS            float64
# COG_DEG                float64
# HEADING_DEG            float64
# NAV_STATUS             float64
# NAV_SENSOR             float64
# SHIP_AND_CARGO_TYPE      int64
# DRAUGHT                float64
# DRAUGHT.1              float64
# DIM_BOW                  int64
# DIM_STERN                int64
# DIM_PORT                 int64
# DIM_STARBOARD            int64
# DESTINATION             object
# MMSI_COUNTRY_CD         object
# RECEIVER                object
# dtype: object

# %%
df['PERIOD'] = pd.to_datetime(df['PERIOD'])
print(df['PERIOD'].dtypes)
# Out:
# datetime64[ns]

# %%
df = df[['MMSI', 'NAME', 'LAT_AVG', 'LON_AVG', 'PERIOD', 'SPEED_KNOTS', 'COG_DEG', 'HEADING_DEG', 'NAV_STATUS', 'SHIP_AND_CARGO_TYPE', 'DRAUGHT', 'DIM_BOW', 'DIM_STERN', 'DIM_PORT', 'DIM_STARBOARD']]
df['BEAM'] = df['DIM_PORT'] + df['DIM_STARBOARD']
df['LENGTH'] = df['DIM_BOW'] + df['DIM_STERN']
df = df[df['BEAM'] > 0]
df = df[df['LENGTH'] > 0]
df = df[df['DRAUGHT'] > 0]
df = df[df['SPEED_KNOTS'] > 3]
df = df.drop_duplicates(subset=['PERIOD', 'MMSI'])

# %%
df['channel_side'] = ['Northwestbound' if x > 200 else 'Southeastbound' for x in df['COG_DEG']]
df = df.sort_values(['MMSI', 'PERIOD']).reset_index(drop=True)
df['time_diff'] = (df.groupby('MMSI')['PERIOD'].diff().dt.total_seconds())
#df['cog_diff'] = (df.groupby('MMSI')['COG_DEG'].diff())
#df['cog_diff'] = np.abs((df['cog_diff'] + 180) % 360 -180)

threshold = 30 * 60 # 30 minutes converted to seconds
df['new_voyage'] = (df['time_diff'] > threshold) | (df['time_diff'] < 0 ) | (df['time_diff'].isna()) #| (df['cog_diff'] > 75)
df['voyage_id'] = (df.groupby('MMSI')['new_voyage'].cumsum())
df['voyage_id'] = df['voyage_id'].astype('str') + '_' + df['MMSI'].astype('str')
df
# Out:
#           MMSI       NAME    LAT_AVG    LON_AVG              PERIOD  \
# 0    215596000     LADY 8  21.984266 -77.231515 2024-04-02 08:00:00
# 1    215596000     LADY 8  22.090150 -77.355984 2024-04-02 08:55:00
# 2    215596000     LADY 8  22.097433 -77.364399 2024-04-02 09:00:00
# 3    215596000     LADY 8  22.205648 -77.489949 2024-04-02 09:55:00
# 4    215596000     LADY 8  22.210693 -77.496115 2024-04-02 10:00:00
# ..         ...        ...        ...        ...                 ...
# 458  760105000  BAP UNION  22.074000 -77.408113 2024-03-20 15:10:00
# 459  760105000  BAP UNION  22.071730 -77.405426 2024-03-20 15:15:00
# 460  760105000  BAP UNION  22.066570 -77.399339 2024-03-20 15:20:00
# 461  760105000  BAP UNION  22.033813 -77.360017 2024-03-20 15:55:00
# 462  760105000  BAP UNION  21.994226 -77.317260 2024-03-20 16:30:00
#
#      SPEED_KNOTS  COG_DEG  HEADING_DEG  NAV_STATUS  SHIP_AND_CARGO_TYPE  ...  \
# 0            9.6    321.5          NaN         0.0                   36  ...
# 1           10.1    308.5          NaN         0.0                   36  ...
# 2           10.0    307.6          NaN         0.0                   36  ...
# 3           10.2    312.1          NaN         0.0                   36  ...
# 4           10.2    305.3          NaN         0.0                   36  ...
# ..           ...      ...          ...         ...                  ...  ...
# 458          5.3    131.5          NaN         3.0                   36  ...
# 459          5.0    131.7          NaN         3.0                   36  ...
# 460          4.9    132.6          NaN         3.0                   36  ...
# 461          5.1    132.7          NaN         3.0                   36  ...
# 462          6.4    133.9          NaN         3.0                   36  ...
#
#      DIM_BOW  DIM_STERN  DIM_PORT  DIM_STARBOARD  BEAM  LENGTH  \
# 0         21          8         6              1     7      29
# 1         21          8         6              1     7      29
# 2         21          8         6              1     7      29
# 3         21          8         6              1     7      29
# 4         21          8         6              1     7      29
# ..       ...        ...       ...            ...   ...     ...
# 458       95         20         6              7    13     115
# 459       95         20         6              7    13     115
# 460       95         20         6              7    13     115
# 461       95         20         6              7    13     115
# 462       95         20         6              7    13     115
#
#        channel_side time_diff  new_voyage    voyage_id
# 0    Northwestbound       NaN        True  1_215596000
# 1    Northwestbound    3300.0        True  2_215596000
# 2    Northwestbound     300.0       False  2_215596000
# 3    Northwestbound    3300.0        True  3_215596000
# 4    Northwestbound     300.0       False  3_215596000
# ..              ...       ...         ...          ...
# 458  Southeastbound     300.0       False  4_760105000
# 459  Southeastbound     300.0       False  4_760105000
# 460  Southeastbound     300.0       False  4_760105000
# 461  Southeastbound    2100.0        True  5_760105000
# 462  Southeastbound    2100.0        True  6_760105000
#
# [463 rows x 21 columns]

# %%
print(f"Total vessels: {df['MMSI'].nunique()}")
print(f"Total voyages: {df['voyage_id'].nunique()}")
# Out:
# Total vessels: 18
# Total voyages: 130

# %%
data = pd.read_csv('obc_boundaries.csv')
data['geometry'] = data.apply(lambda x: (float(x.Long), float(x.Lat)), axis=1)
channel_coords = list(data['geometry'])
channel_coords_north = [channel_coords[0], channel_coords[1], channel_coords[2], channel_coords[3], channel_coords[-1], channel_coords[-2], channel_coords[-3], channel_coords[-4]]
channel_coords_south = [channel_coords[4], channel_coords[5], channel_coords[6], channel_coords[7], channel_coords[-1], channel_coords[-2], channel_coords[-3], channel_coords[-4]]
coords_north = [channel_coords[0], channel_coords[1], channel_coords[2], (-77.44235, 22.18378333), (-77.44235, 23.80836667), (-78.72296667, 23.80836667)]
coords_south = [channel_coords[4], channel_coords[5], channel_coords[6], channel_coords[7], (-77.4681,21.15348333), (-78.75143333, 21.15348333)]
channel_polygon_n = Polygon(channel_coords_north)
channel_polygon_s = Polygon(channel_coords_south)
polygon_n = Polygon(coords_north)
polygon_s = Polygon(coords_south)

# %%
def where_is_vessel(LAT_AVG, LON_AVG, BOOL_northc, BOOL_southc, BOOL_north, BOOL_south):
    if BOOL_northc == True:
        answer = 'in north channel'
    elif BOOL_southc == True:
        answer = 'in south channel'
    elif LON_AVG < -78.72296667:
        answer = 'west'
    elif LON_AVG > -77.49385:
        answer = 'east'
    elif BOOL_north == True:
        answer = 'north'
    elif BOOL_south == True:
        answer = 'south'
    else:
        answer = 'other'
    return answer

# %%
geo_df = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df['LON_AVG'], df['LAT_AVG']), crs='EPSG:4326')
geo_df['in_channel_north'] = geo_df.within(channel_polygon_n)
geo_df['in_channel_south'] = geo_df.within(channel_polygon_s)
geo_df['north_of_channel'] = geo_df.within(polygon_n)
geo_df['south_of_channel'] = geo_df.within(polygon_s)
geo_df['location'] = geo_df.apply(lambda x: where_is_vessel(x.LAT_AVG, x.LON_AVG, x.in_channel_north, x.in_channel_south, x.north_of_channel, x.south_of_channel), axis=1)
geo_df.shape
# Out:
# (463, 27)

# %%
geo_df['location'].value_counts()
# Out:
# location
# east                171
# north               127
# west                 90
# in south channel     30
# in north channel     29
# south                16
# Name: count, dtype: int64

# %%
voyage_list = list(geo_df['voyage_id'].unique())
random_voyages = rand.sample(voyage_list, 40)
geo_df['include'] = geo_df['voyage_id'].isin(random_voyages)
random_voyages_gdf = geo_df[geo_df['include'] == True]
random_voyages_gdf.shape
# Out:
# (124, 28)

# %%
data = pd.read_csv('obc_boundaries.csv')
from shapely.geometry import Point
from shapely.geometry import Polygon
data = data[data['Line']!='Middle']
data['geometry'] = data.apply(lambda x: (float(x.Long), float(x.Lat)), axis=1)

channel_coords = list(data['geometry'])
channel_coords_reorder = [channel_coords[0], channel_coords[1], channel_coords[2], channel_coords[3], channel_coords[-1], channel_coords[-2], channel_coords[-3], channel_coords[-4]]
channel_polygon = Polygon(channel_coords_reorder)
geo_df_channel = geopandas.GeoDataFrame(geometry=[channel_polygon], crs='EPSG:4326')

# %%
my_map = folium.Map(location=[22.5, -77.8], zoom_start=9.45)
folium.GeoJson(geo_df_channel).add_to(my_map)

def rand_color():
    return "#{:06x}".format(rand.randint(0, 0xFFFFFF))

for id, vessel in random_voyages_gdf.groupby('voyage_id'):
    coords = list(vessel[['LAT_AVG', 'LON_AVG']].itertuples(index=False, name=None))

    folium.PolyLine(
        coords,
        color=rand_color(),
        weight=2,
        opacity=0.8,
        popup=f"MMSI: {id}"
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39c7f841ae427a05d313ec0692adea44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39c7f841ae427a05d313ec0692adea44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39c7f841ae427a05d313ec0692adea44 = L.map(
#                 &quot;map_39c7f841ae427a05d313ec0692adea44&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9.45,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba0c041fa3dda4aa079cb2e29d370a99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba0c041fa3dda4aa079cb2e29d370a99.addTo(map_39c7f841ae427a05d313ec0692adea44);
#
#
#
#         function geo_json_b5c16326af08f6fc3563e46f2421e1ea_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b5c16326af08f6fc3563e46f2421e1ea = L.geoJson(null, {
#                 onEachFeature: geo_json_b5c16326af08f6fc3563e46f2421e1ea_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_b5c16326af08f6fc3563e46f2421e1ea_add (data) {
#             geo_json_b5c16326af08f6fc3563e46f2421e1ea
#                 .addData(data);
#         }
#             geo_json_b5c16326af08f6fc3563e46f2421e1ea_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_b5c16326af08f6fc3563e46f2421e1ea.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_b5c16326af08f6fc3563e46f2421e1ea.addTo(map_39c7f841ae427a05d313ec0692adea44);
#
#
#             var poly_line_04b9c9f725155956937edcfa9fec6aa5 = L.polyline(
#                 [[22.641223, -78.367199], [22.631535, -78.336437], [22.623821, -78.312389]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#9b8d53&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#9b8d53&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_39c7f841ae427a05d313ec0692adea44);
#
#
#         var popup_4a8804f79fdc800d3ae642c4b2e71cf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f54688c014eaf064b909ddae36a7377 = $(`&lt;div id=&quot;html_4f54688c014eaf064b909ddae36a7377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MMSI: 10_367609150&lt;/div&gt;`)[0];
#                 popup_4a8804f79fdc800d3ae642c4b2e71cf0.setContent(html_4f54688c014eaf064b909ddae36a7377);
#
#
#
#         poly_line_04b9c9f725155956937edcfa9fec6aa5.bindPopup(popup_4a8804f79fdc800d3ae642c4b2e71cf0)
#         ;
#
#
#
#
#             var poly_line_472e0548cfd4d68132378887c50d1cda = L.polyline(
#                 [[22.002716, -77.10665], [22.002106, -77.105725]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3ed1f6&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3ed1f6&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_39c7f841ae427a05d313ec0692adea44);
#
#
#         var popup_a062183aa2a5726befec3908b9fd17f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eea38dbc54bcb7fec2902e7ff150d174 = $(`&lt;div id=&quot;html_eea38dbc54bcb7fec2902e7ff150d174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MMSI: 10_368022550&lt;/div&gt;`)[0];

# %%
new_threshold = 60 * 60 # 60 minutes converted to seconds
df['new_voyage'] = (df['time_diff'] > new_threshold) | (df['time_diff'] < 0 ) | (df['time_diff'].isna()) #| (df['cog_diff'] > 75)
df['voyage_id'] = (df.groupby('MMSI')['new_voyage'].cumsum())
df['voyage_id'] = df['voyage_id'].astype('str') + '_' + df['MMSI'].astype('str')
print(f"Total vessels: {df['MMSI'].nunique()}")
print(f"Total voyages: {df['voyage_id'].nunique()}")
# Out:
# Total vessels: 18
# Total voyages: 94

# %%
new_threshold = 3 * 60 * 60 # 3 hours converted to seconds
df['new_voyage'] = (df['time_diff'] > new_threshold) | (df['time_diff'] < 0 ) | (df['time_diff'].isna()) #| (df['cog_diff'] > 75)
df['voyage_id'] = (df.groupby('MMSI')['new_voyage'].cumsum())
df['voyage_id'] = df['voyage_id'].astype('str') + '_' + df['MMSI'].astype('str')
print(f"Total vessels: {df['MMSI'].nunique()}")
print(f"Total voyages: {df['voyage_id'].nunique()}")
# Out:
# Total vessels: 18
# Total voyages: 48

# %%
my_map = folium.Map(location=[22.5, -77.8], zoom_start=9.45)
folium.GeoJson(geo_df_channel).add_to(my_map)

def rand_color():
    return "#{:06x}".format(rand.randint(0, 0xFFFFFF))

for id, vessel in df.groupby('voyage_id'):
    coords = list(vessel[['LAT_AVG', 'LON_AVG']].itertuples(index=False, name=None))

    folium.PolyLine(
        coords,
        color=rand_color(),
        weight=2,
        opacity=0.8,
        popup=f"MMSI: {id}"
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d42ed9f78334ee56db7889ae58571aad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d42ed9f78334ee56db7889ae58571aad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d42ed9f78334ee56db7889ae58571aad = L.map(
#                 &quot;map_d42ed9f78334ee56db7889ae58571aad&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9.45,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34268396ce827426210436ec88512ed1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34268396ce827426210436ec88512ed1.addTo(map_d42ed9f78334ee56db7889ae58571aad);
#
#
#
#         function geo_json_b2a9f64711eec0992fb59f965273f342_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_b2a9f64711eec0992fb59f965273f342 = L.geoJson(null, {
#                 onEachFeature: geo_json_b2a9f64711eec0992fb59f965273f342_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_b2a9f64711eec0992fb59f965273f342_add (data) {
#             geo_json_b2a9f64711eec0992fb59f965273f342
#                 .addData(data);
#         }
#             geo_json_b2a9f64711eec0992fb59f965273f342_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_b2a9f64711eec0992fb59f965273f342.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_b2a9f64711eec0992fb59f965273f342.addTo(map_d42ed9f78334ee56db7889ae58571aad);
#
#
#             var poly_line_4c7556a6dc405a779b9dc9642d65854c = L.polyline(
#                 [[21.984266, -77.231515], [22.09015, -77.355984], [22.097433, -77.364399], [22.205648, -77.489949], [22.210693, -77.496115]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#c28176&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#c28176&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_d42ed9f78334ee56db7889ae58571aad);
#
#
#         var popup_7ae46a74e1b9524b6a67202f01b6d0ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae73a3f898632d0036b8f5710e8d8b1d = $(`&lt;div id=&quot;html_ae73a3f898632d0036b8f5710e8d8b1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MMSI: 1_215596000&lt;/div&gt;`)[0];
#                 popup_7ae46a74e1b9524b6a67202f01b6d0ea.setContent(html_ae73a3f898632d0036b8f5710e8d8b1d);
#
#
#
#         poly_line_4c7556a6dc405a779b9dc9642d65854c.bindPopup(popup_7ae46a74e1b9524b6a67202f01b6d0ea)
#         ;
#
#
#
#
#             var poly_line_3e0349a7f2a16fadbe3e83318b12a204 = L.polyline(
#                 [[22.121647, -77.348564], [22.207855, -77.479347]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#99d2ee&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#99d2ee&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_d42ed9f78334ee56db7889ae58571aad);
#
#
#         var popup_4c329660420ee0a05472e529076585ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_589c77a3d9363c9cba8adbca9f4da89a = $(`&lt;div id=&quot;html_589c77a3d9363c9cba8adbca9f4da89a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;MM

# %%
my_map = folium.Map(location=[22.5, -77.8], zoom_start=9.45)
folium.GeoJson(geo_df_channel).add_to(my_map)

def rand_color():
    return "#{:06x}".format(rand.randint(0, 0xFFFFFF))

for id, vessel in df.groupby('MMSI'):
    coords = list(vessel[['LAT_AVG', 'LON_AVG']].itertuples(index=False, name=None))

    folium.PolyLine(
        coords,
        color=rand_color(),
        weight=2,
        opacity=0.8,
        tooltip=f"MMSI: {id}"
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_571d9e3505f2a7bbcf6b0e0205e1771a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_571d9e3505f2a7bbcf6b0e0205e1771a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_571d9e3505f2a7bbcf6b0e0205e1771a = L.map(
#                 &quot;map_571d9e3505f2a7bbcf6b0e0205e1771a&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9.45,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a763cce43ec48261c08c83f66dcff6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a763cce43ec48261c08c83f66dcff6a.addTo(map_571d9e3505f2a7bbcf6b0e0205e1771a);
#
#
#
#         function geo_json_8c27eb063ce4d8891ebb4230b2c9b332_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_8c27eb063ce4d8891ebb4230b2c9b332 = L.geoJson(null, {
#                 onEachFeature: geo_json_8c27eb063ce4d8891ebb4230b2c9b332_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_8c27eb063ce4d8891ebb4230b2c9b332_add (data) {
#             geo_json_8c27eb063ce4d8891ebb4230b2c9b332
#                 .addData(data);
#         }
#             geo_json_8c27eb063ce4d8891ebb4230b2c9b332_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_8c27eb063ce4d8891ebb4230b2c9b332.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_8c27eb063ce4d8891ebb4230b2c9b332.addTo(map_571d9e3505f2a7bbcf6b0e0205e1771a);
#
#
#             var poly_line_761d9852ebe25fc439b5013a75621c53 = L.polyline(
#                 [[21.984266, -77.231515], [22.09015, -77.355984], [22.097433, -77.364399], [22.205648, -77.489949], [22.210693, -77.496115], [22.901465, -79.000415]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#4c3292&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#4c3292&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_571d9e3505f2a7bbcf6b0e0205e1771a);
#
#
#             poly_line_761d9852ebe25fc439b5013a75621c53.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI: 215596000
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_ee10aa005e2c66242f15025fbdfbc806 = L.polyline(
#                 [[22.121647, -77.348564], [22.207855, -77.479347]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#20d3f4&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#20d3f4&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_571d9e3505f2a7bbcf6b0e0205e1771a);
#
#
#             poly_line_ee10aa005e2c66242f15025fbdfbc806.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI: 218768000
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_ba1f0cf33cdf5539be08036dbdb8324b = L.polyline(
#                 [[22.0708, -77.177855]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#b2a188&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#b2a188&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd

# %%
weird_mmsi = [367609150, 355187000, 338327000]
mask = df["MMSI"].isin(weird_mmsi)
print(mask.sum())  # number of matching rows
# Out:
# 174

# %%
weird_df = df[df["MMSI"].isin(weird_mmsi)]

# %%
my_map = folium.Map(location=[22.5, -77.8], zoom_start=9.45)
folium.GeoJson(geo_df_channel).add_to(my_map)

def rand_color():
    return "#{:06x}".format(rand.randint(0, 0xFFFFFF))

for id, vessel in weird_df.groupby('MMSI'):
    coords = list(vessel[['LAT_AVG', 'LON_AVG']].itertuples(index=False, name=None))

    folium.PolyLine(
        coords,
        color=rand_color(),
        weight=2,
        opacity=0.8,
        tooltip=f"MMSI: {id}"
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32efc6142c4b3bf57e4c5dc4faaaef4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32efc6142c4b3bf57e4c5dc4faaaef4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32efc6142c4b3bf57e4c5dc4faaaef4a = L.map(
#                 &quot;map_32efc6142c4b3bf57e4c5dc4faaaef4a&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9.45,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c64fcea296128e23b704ab78b530a56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c64fcea296128e23b704ab78b530a56.addTo(map_32efc6142c4b3bf57e4c5dc4faaaef4a);
#
#
#
#         function geo_json_3c02f5c75bfd967067057770550e5744_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_3c02f5c75bfd967067057770550e5744 = L.geoJson(null, {
#                 onEachFeature: geo_json_3c02f5c75bfd967067057770550e5744_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_3c02f5c75bfd967067057770550e5744_add (data) {
#             geo_json_3c02f5c75bfd967067057770550e5744
#                 .addData(data);
#         }
#             geo_json_3c02f5c75bfd967067057770550e5744_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_3c02f5c75bfd967067057770550e5744.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3c02f5c75bfd967067057770550e5744.addTo(map_32efc6142c4b3bf57e4c5dc4faaaef4a);
#
#
#             var poly_line_7841d5fbb394110a160fd36013b73c9a = L.polyline(
#                 [[21.90461, -76.74784], [21.970248, -76.891947], [22.00569, -76.98367], [22.039066, -77.073747], [22.042758, -77.083767], [22.05671, -77.135514], [22.060998, -77.151394], [22.071533, -77.18348], [22.276848, -77.508834], [22.357609, -77.642407], [22.377356, -77.668327], [22.387466, -77.68088], [22.392745, -77.687487], [22.393151, -77.68794], [22.428318, -77.730847], [22.496728, -77.818147], [22.628276, -78.07658], [22.631135, -78.08366], [22.634074, -78.091215], [22.642053, -78.112402], [22.66246, -78.166007], [22.673441, -78.192267], [22.683003, -78.211757], [22.685445, -78.21688], [22.690165, -78.22682], [22.702356, -78.252794], [22.717318, -78.283947], [22.72022, -78.290207], [22.720626, -78.29144], [22.727218, -78.307447], [22.744674, -78.341443], [22.746691, -78.345007], [22.839152, -78.494953], [22.918666, -78.621894], [23.024536, -78.76418], [23.061825, -78.79676], [23.209391, -78.893894], [23.246611, -78.91338], [23.252913, -78.91726], [21.873271, -76.743674], [21.887553, -76.78018], [21.98794, -77.08498], [22.184823, -77.379427], [22.433361, -77.756107], [22.438696, -77.76486], [22.44332, -77.772114], [22.448715, -77.780227], [22.45313, -77.78846], [22.458378, -77.796614], [22.4639, -77.804667], [22.470211, -77.812354], [22.475761, -77.81988], [22.481986, -77.827614], [22.488795, -77.835467], [22.494675, -77.84358], [22.500778, -77.851787], [22.506816, -77.859914], [22.513196, -77.868387], [22.518661, -77.875887], [22.652958, -78.077134], [22.653466, -78.079127], [22.695533, -78.229794], [22.702825, -78.259434], [23.183911, -78.887047]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#cc19ce&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#cc19ce&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_32efc6142c4b3bf57e4c5dc4faaaef4a);
#
#
#             poly_line_7841d5fbb394110a160fd36013b73c9a.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI: 338327000
#                  &lt;/div&gt;`,
#                 {
#   &quot;s

# %%
new_threshold = 6 * 60 * 60 # 3 hours converted to seconds
weird_df['new_voyage'] = (weird_df['time_diff'] > new_threshold) | (weird_df['time_diff'] < 0 ) | (weird_df['time_diff'].isna()) #| (df['cog_diff'] > 75)
weird_df['voyage_id'] = (weird_df.groupby('MMSI')['new_voyage'].cumsum())
weird_df['voyage_id'] = weird_df['voyage_id'].astype('str') + '_' + weird_df['MMSI'].astype('str')
print(f"Total vessels: {weird_df['MMSI'].nunique()}")
print(f"Total voyages: {weird_df['voyage_id'].nunique()}")
# Out:
# Total vessels: 3
# Total voyages: 7
# C:\Users\LAKwon\AppData\Local\Temp\ipykernel_18660\35814225.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weird_df['new_voyage'] = (weird_df['time_diff'] > new_threshold) | (weird_df['time_diff'] < 0 ) | (weird_df['time_diff'].isna()) #| (df['cog_diff'] > 75)
# C:\Users\LAKwon\AppData\Local\Temp\ipykernel_18660\35814225.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weird_df['voyage_id'] = (weird_df.groupby('MMSI')['new_voyage'].cumsum())
# C:\Users\LAKwon\AppData\Local\Temp\ipykernel_18660\35814225.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weird_df['voyage_id'] = weird_df['voyage_id'].astype('str') + '_' + weird_df['MMSI'].astype('str')

# %%
my_map = folium.Map(location=[22.5, -77.8], zoom_start=9.45)
folium.GeoJson(geo_df_channel).add_to(my_map)

def rand_color():
    return "#{:06x}".format(rand.randint(0, 0xFFFFFF))

for id, vessel in weird_df.groupby('voyage_id'):
    coords = list(vessel[['LAT_AVG', 'LON_AVG']].itertuples(index=False, name=None))

    folium.PolyLine(
        coords,
        color=rand_color(),
        weight=2,
        opacity=0.8,
        tooltip=f"voyage id: {id}"
    ).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e941878904e43cffdaf80a15543a1c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e941878904e43cffdaf80a15543a1c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e941878904e43cffdaf80a15543a1c2 = L.map(
#                 &quot;map_0e941878904e43cffdaf80a15543a1c2&quot;,
#                 {
#                     center: [22.5, -77.8],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 9.45,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_476c201356ec9e1308ff5ba8d3447885 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_476c201356ec9e1308ff5ba8d3447885.addTo(map_0e941878904e43cffdaf80a15543a1c2);
#
#
#
#         function geo_json_dd6b3fc6cd536e24918a0ab6e743cb78_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_dd6b3fc6cd536e24918a0ab6e743cb78 = L.geoJson(null, {
#                 onEachFeature: geo_json_dd6b3fc6cd536e24918a0ab6e743cb78_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_dd6b3fc6cd536e24918a0ab6e743cb78_add (data) {
#             geo_json_dd6b3fc6cd536e24918a0ab6e743cb78
#                 .addData(data);
#         }
#             geo_json_dd6b3fc6cd536e24918a0ab6e743cb78_add({&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;features&quot;: [{&quot;bbox&quot;: [-78.78395, 22.12445, -77.44235, 22.84101667], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-78.72296667, 22.84101667], [-78.0874, 22.62481667], [-77.63613333, 22.3528], [-77.44235, 22.18378333], [-77.49385, 22.12445], [-77.68085, 22.2885], [-78.13211667, 22.55308333], [-78.78395, 22.77695], [-78.72296667, 22.84101667]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_dd6b3fc6cd536e24918a0ab6e743cb78.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_dd6b3fc6cd536e24918a0ab6e743cb78.addTo(map_0e941878904e43cffdaf80a15543a1c2);
#
#
#             var poly_line_c419c53606a05acb088cff3889d9400a = L.polyline(
#                 [[21.90461, -76.74784], [21.970248, -76.891947], [22.00569, -76.98367], [22.039066, -77.073747], [22.042758, -77.083767], [22.05671, -77.135514], [22.060998, -77.151394], [22.071533, -77.18348], [22.276848, -77.508834], [22.357609, -77.642407], [22.377356, -77.668327], [22.387466, -77.68088], [22.392745, -77.687487], [22.393151, -77.68794], [22.428318, -77.730847], [22.496728, -77.818147], [22.628276, -78.07658], [22.631135, -78.08366], [22.634074, -78.091215], [22.642053, -78.112402], [22.66246, -78.166007], [22.673441, -78.192267], [22.683003, -78.211757], [22.685445, -78.21688], [22.690165, -78.22682], [22.702356, -78.252794], [22.717318, -78.283947], [22.72022, -78.290207], [22.720626, -78.29144], [22.727218, -78.307447], [22.744674, -78.341443], [22.746691, -78.345007], [22.839152, -78.494953], [22.918666, -78.621894], [23.024536, -78.76418], [23.061825, -78.79676], [23.209391, -78.893894], [23.246611, -78.91338], [23.252913, -78.91726]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#058f25&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#058f25&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_0e941878904e43cffdaf80a15543a1c2);
#
#
#             poly_line_c419c53606a05acb088cff3889d9400a.bindTooltip(
#                 `&lt;div&gt;
#                      voyage id: 1_338327000
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_eaceb5c368f77654a9a98ef9e77efaa9 = L.polyline(
#                 [[21.81856, -77.005859], [21.974395, -77.219865], [22.043575, -77.305023], [22.0512, -77.313514], [22.129266, -77.406185], [22.211845, -77.498587], [22.373418, -77.710115], [22.381153, -77.720822], [22.485856, -77.886705], [22.702191, -78.36538], [22.738723, -78.476517], [22.775103, -78.588765], [22.80889, -78.699915], [22.910895, -78.963339], [22.91705, -78.979064], [22.923323, -78.994735], [22.952998, -79.071454], [22.961606, -79.093265], [23.018801, -79.24857]]

# %%
weird_df["time_diff"]= weird_df["time_diff"].fillna(0)
max_dt = max(weird_df['time_diff'])
print(max_dt)
# Out:
# 30169200.0
# C:\Users\LAKwon\AppData\Local\Temp\ipykernel_18660\3121434828.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   weird_df["time_diff"]= weird_df["time_diff"].fillna(0)

# %%
print(max_dt)
# Out:
# 8380.333333333334

# %%
weird_df.to_csv("weird_sail.csv")

# %%
print(3*60*60)
# Out:
# 10800

# %% [markdown]
# Weird because after 2100ish the AIS pings stop coming in then they come back at 0000. They still follow the same path and look like they were moving the whole time in the same direction. Nothing shady happening. Weird stuff. That's why in these three vessels, there were multiple routes down the same length.
