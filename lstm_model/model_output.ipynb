# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Model classes
class Encoder(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers)

    def forward(self, x):
        _, (hidden, cell) = self.lstm(x)
        return hidden, cell


class Decoder(nn.Module):
    def __init__(self, output_size, hidden_size, num_layers):
        super().__init__()
        self.lstm = nn.LSTM(output_size, hidden_size, num_layers)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x, hidden, cell):
        out, (hidden, cell) = self.lstm(x, (hidden, cell))
        pred = self.linear(out[-1])
        return pred, hidden, cell


class EncoderDecoderLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super().__init__()
        self.encoder = Encoder(input_size, hidden_size, num_layers)
        self.decoder = Decoder(output_size, hidden_size, num_layers)

    def forward(self, x, target_len):
        hidden, cell = self.encoder(x)
        decoder_input = x[-1, :, :2].unsqueeze(0)   # last LAT/LON
        outputs = []

        for _ in range(target_len):
            pred, hidden, cell = self.decoder(decoder_input, hidden, cell)
            outputs.append(pred)
            decoder_input = pred.unsqueeze(0)

        return torch.stack(outputs, dim=0)


# Build windows
def make_input_windows(df, feature_cols, seq_len=20):
    X_list = []

    values = df[feature_cols].to_numpy(dtype=np.float32)

    for i in range(len(df) - seq_len + 1):
        x_window = values[i:i+seq_len]
        X_list.append(x_window)

    X = np.stack(X_list)                  # (N, seq_len, features)
    X = np.transpose(X, (1, 0, 2))        # (seq_len, N, features)
    return torch.tensor(X, dtype=torch.float32)


# Read test file
df = pd.read_csv("model_data/gold_test_data.csv")





# Make model input
feature_cols = ["LAT", "LON", "SPEED", "dt", "cog_sin", "cog_cos", "hdg_sin", "hdg_cos"]
seq_len = 20
target_len = 2

X_test = make_input_windows(df, feature_cols, seq_len=seq_len).to(device)

print("X_test shape:", X_test.shape)   # should be (seq_len, N, 8)


# Load model
input_size = 8
hidden_size = 128   # replace with your trained value
num_layers = 3      # based on your saved checkpoint
output_size = 2

model = EncoderDecoderLSTM(
    input_size=input_size,
    hidden_size=hidden_size,
    num_layers=num_layers,
    output_size=output_size
).to(device)

model.load_state_dict(torch.load("best_model.pt", map_location=device))
model.eval()


# Predict
with torch.no_grad():
    pred = model(X_test, target_len=target_len)

pred = pred.cpu().numpy()   # (target_len, N, 2)
# Out:
# X_test shape: torch.Size([20, 3361, 8])

# %%
import folium

# Center map on first history point
history = X_test[:, 0, :2].cpu().numpy()
preds = pred[:, 0, :]

center_lat = history[0, 0]
center_lon = history[0, 1]

m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

# History points
history_coords = [(row[0], row[1]) for row in history]

# Predicted points
pred_coords = [(row[0], row[1]) for row in preds]

# Draw history track
folium.PolyLine(
    history_coords,
    weight=3,
    tooltip="History"
).add_to(m)

# Add last point marker
folium.Marker(
    location=list(history_coords[-1]),
    popup="Last ping",
    tooltip="Last ping"
).add_to(m)

# Draw predicted track
folium.PolyLine(
    pred_coords,
    weight=3,
    dash_array="5, 8",
    tooltip="Predicted"
).add_to(m)

# Add markers for history
for i, (lat, lon) in enumerate(history_coords):
    folium.CircleMarker(
        location=[lat, lon],
        radius=3,
        popup=f"History {i}",
        fill=True
    ).add_to(m)

# Add markers for predicted points
for i, (lat, lon) in enumerate(pred_coords, start=1):
    folium.Marker(
        location=[lat, lon],
        popup=f"Predicted {i}",
        tooltip=f"Predicted {i}"
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_748c60daa10f7ee130e83d180c632b18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_748c60daa10f7ee130e83d180c632b18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_748c60daa10f7ee130e83d180c632b18 = L.map(
#                 &quot;map_748c60daa10f7ee130e83d180c632b18&quot;,
#                 {
#                     center: [21.938385009765625, -77.26986694335938],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f4d470577e0aa9e26be64a67a2f0325 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f4d470577e0aa9e26be64a67a2f0325.addTo(map_748c60daa10f7ee130e83d180c632b18);
#
#
#             var poly_line_f7fba32d48c2ba37f4357eb0cad4b6bf = L.polyline(
#                 [[21.938385009765625, -77.26986694335938], [21.933635711669922, -77.26460266113281], [21.91769027709961, -77.24693298339844], [21.897485733032227, -77.22404479980469], [21.87637710571289, -77.20001220703125], [21.859695434570312, -77.1808853149414], [21.832847595214844, -77.15045928955078], [22.248676300048828, -77.55010223388672], [22.29853057861328, -77.60879516601562], [22.351890563964844, -77.68450927734375], [22.37944221496582, -77.7303695678711], [22.40825080871582, -77.7779312133789], [22.422971725463867, -77.80221557617188], [22.509387969970703, -77.9432144165039], [22.521249771118164, -77.96253967285156], [22.533523559570312, -77.98270416259766], [22.545068740844727, -78.00159454345703], [22.55115509033203, -78.01141357421875], [23.014495849609375, -79.27204132080078], [23.01920509338379, -79.28423309326172]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_748c60daa10f7ee130e83d180c632b18);
#
#
#             poly_line_f7fba32d48c2ba37f4357eb0cad4b6bf.bindTooltip(
#                 `&lt;div&gt;
#                      History
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f20d9473bafb0d73af637cbeb1694214 = L.marker(
#                 [23.01920509338379, -79.28423309326172],
#                 {
# }
#             ).addTo(map_748c60daa10f7ee130e83d180c632b18);
#
#
#         var popup_5c588e24139c563926f7f90360361862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30571bac972cecb6825de176f7b21565 = $(`&lt;div id=&quot;html_30571bac972cecb6825de176f7b21565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Last ping&lt;/div&gt;`)[0];
#                 popup_5c588e24139c563926f7f90360361862.setContent(html_30571bac972cecb6825de176f7b21565);
#
#
#
#         marker_f20d9473bafb0d73af637cbeb1694214.bindPopup(popup_5c588e24139c563926f7f90360361862)
#         ;
#
#
#
#
#             marker_f20d9473bafb0d73af637cbeb1694214.bindTooltip(
#                 `&lt;div&gt;
#                      Last ping
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_86981510ad8269fae21e47d1d20089d5 = L.polyline(
#                 [[22.249732971191406, -75.65274047851562], [22.602970123291016, -78.05504608154297]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: &quot;5, 8&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_748c60daa10f7ee130e83d180c632b18);
#
#
#             poly_line_86981510ad8269fae21e47d1d20089d5.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_0754f9b9384910a17518e9d6ebc77558 = L.ci

# %%
def mapmake(history, prediction):
    m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

    # History points
    history_coords = [(row[0], row[1]) for row in history]

    # Predicted points
    pred_coords = [(row[0], row[1]) for row in prediction]

    # Draw history track
    folium.PolyLine(
        history_coords,
        weight=3,
        tooltip="History"
    ).add_to(m)

    # Add last point marker
    folium.Marker(
        location=list(history_coords[-1]),
        popup="Last ping",
        tooltip="Last ping"
    ).add_to(m)

    # Draw predicted track
    folium.PolyLine(
        pred_coords,
        weight=3,
        dash_array="5, 8",
        tooltip="Predicted"
    ).add_to(m)

    # Add markers for history
    for i, (lat, lon) in enumerate(history_coords):
        folium.CircleMarker(
            location=[lat, lon],
            radius=3,
            popup=f"History {i}",
            fill=True
        ).add_to(m)

    # Add markers for predicted points
    for i, (lat, lon) in enumerate(pred_coords, start=1):
        folium.Marker(
            location=[lat, lon],
            popup=f"Predicted {i}",
            tooltip=f"Predicted {i}"
        ).add_to(m)

    return m

# %%
history_2 = X_test[:, 1, :2].cpu().numpy()
preds_2 = pred[:, 1, :]
mapmake(history_2, preds_2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_989840d5c3c8fda623de96497d38f340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_989840d5c3c8fda623de96497d38f340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_989840d5c3c8fda623de96497d38f340 = L.map(
#                 &quot;map_989840d5c3c8fda623de96497d38f340&quot;,
#                 {
#                     center: [21.938385009765625, -77.26986694335938],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1915ece82fc0d7737803eb1486196321 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1915ece82fc0d7737803eb1486196321.addTo(map_989840d5c3c8fda623de96497d38f340);
#
#
#             var poly_line_085d7adb84b5610688a1b177e594ec0e = L.polyline(
#                 [[21.933635711669922, -77.26460266113281], [21.91769027709961, -77.24693298339844], [21.897485733032227, -77.22404479980469], [21.87637710571289, -77.20001220703125], [21.859695434570312, -77.1808853149414], [21.832847595214844, -77.15045928955078], [22.248676300048828, -77.55010223388672], [22.29853057861328, -77.60879516601562], [22.351890563964844, -77.68450927734375], [22.37944221496582, -77.7303695678711], [22.40825080871582, -77.7779312133789], [22.422971725463867, -77.80221557617188], [22.509387969970703, -77.9432144165039], [22.521249771118164, -77.96253967285156], [22.533523559570312, -77.98270416259766], [22.545068740844727, -78.00159454345703], [22.55115509033203, -78.01141357421875], [23.014495849609375, -79.27204132080078], [23.01920509338379, -79.28423309326172], [23.030868530273438, -79.31459045410156]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_989840d5c3c8fda623de96497d38f340);
#
#
#             poly_line_085d7adb84b5610688a1b177e594ec0e.bindTooltip(
#                 `&lt;div&gt;
#                      History
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_235e897cd6ef28d00e8afe5cb941ade4 = L.marker(
#                 [23.030868530273438, -79.31459045410156],
#                 {
# }
#             ).addTo(map_989840d5c3c8fda623de96497d38f340);
#
#
#         var popup_256bc48b5a5da464ee4dfd467ac26cc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ea9474020684ab144628be3d3b7c584 = $(`&lt;div id=&quot;html_3ea9474020684ab144628be3d3b7c584&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Last ping&lt;/div&gt;`)[0];
#                 popup_256bc48b5a5da464ee4dfd467ac26cc0.setContent(html_3ea9474020684ab144628be3d3b7c584);
#
#
#
#         marker_235e897cd6ef28d00e8afe5cb941ade4.bindPopup(popup_256bc48b5a5da464ee4dfd467ac26cc0)
#         ;
#
#
#
#
#             marker_235e897cd6ef28d00e8afe5cb941ade4.bindTooltip(
#                 `&lt;div&gt;
#                      Last ping
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_6d513b60e064f274ee3853af6252615c = L.polyline(
#                 [[22.249732971191406, -75.65274047851562], [22.602970123291016, -78.05504608154297]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: &quot;5, 8&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_989840d5c3c8fda623de96497d38f340);
#
#
#             poly_line_6d513b60e064f274ee3853af6252615c.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_86f651b3d0587d6749035acc959fa9ae = L.c

# %%
history_3 = X_test[:, 9, :2].cpu().numpy()
preds_3 = pred[:, 9, :]
mapmake(history_3, preds_3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e0cba7b3c2fa648b0a35934a6aed926 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e0cba7b3c2fa648b0a35934a6aed926&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e0cba7b3c2fa648b0a35934a6aed926 = L.map(
#                 &quot;map_1e0cba7b3c2fa648b0a35934a6aed926&quot;,
#                 {
#                     center: [21.938385009765625, -77.26986694335938],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d227cad1d2122c71b7958ae673aa1063 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d227cad1d2122c71b7958ae673aa1063.addTo(map_1e0cba7b3c2fa648b0a35934a6aed926);
#
#
#             var poly_line_12bf428bd573c8a6ec9ec74a9f715250 = L.polyline(
#                 [[22.351890563964844, -77.68450927734375], [22.37944221496582, -77.7303695678711], [22.40825080871582, -77.7779312133789], [22.422971725463867, -77.80221557617188], [22.509387969970703, -77.9432144165039], [22.521249771118164, -77.96253967285156], [22.533523559570312, -77.98270416259766], [22.545068740844727, -78.00159454345703], [22.55115509033203, -78.01141357421875], [23.014495849609375, -79.27204132080078], [23.01920509338379, -79.28423309326172], [23.030868530273438, -79.31459045410156], [23.035690307617188, -79.3271255493164], [23.045095443725586, -79.35125732421875], [22.216754913330078, -77.5838623046875], [22.202350616455078, -77.56800842285156], [22.17510414123535, -77.53802490234375], [22.16599464416504, -77.5281982421875], [22.156911849975586, -77.51835632324219], [22.14017677307129, -77.50050354003906]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e0cba7b3c2fa648b0a35934a6aed926);
#
#
#             poly_line_12bf428bd573c8a6ec9ec74a9f715250.bindTooltip(
#                 `&lt;div&gt;
#                      History
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5dc787c548715bcea7492d0264cf0967 = L.marker(
#                 [22.14017677307129, -77.50050354003906],
#                 {
# }
#             ).addTo(map_1e0cba7b3c2fa648b0a35934a6aed926);
#
#
#         var popup_1aaefac25af2ffb965af64e7e3ab5111 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b3fc519927e29dedff60608da0f3bba = $(`&lt;div id=&quot;html_8b3fc519927e29dedff60608da0f3bba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Last ping&lt;/div&gt;`)[0];
#                 popup_1aaefac25af2ffb965af64e7e3ab5111.setContent(html_8b3fc519927e29dedff60608da0f3bba);
#
#
#
#         marker_5dc787c548715bcea7492d0264cf0967.bindPopup(popup_1aaefac25af2ffb965af64e7e3ab5111)
#         ;
#
#
#
#
#             marker_5dc787c548715bcea7492d0264cf0967.bindTooltip(
#                 `&lt;div&gt;
#                      Last ping
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var poly_line_1f453fc4f4f3f909cdeafdb2bdaa1fc9 = L.polyline(
#                 [[22.249732971191406, -75.65274047851562], [22.602970123291016, -78.05504608154297]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: &quot;5, 8&quot;, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e0cba7b3c2fa648b0a35934a6aed926);
#
#
#             poly_line_1f453fc4f4f3f909cdeafdb2bdaa1fc9.bindTooltip(
#                 `&lt;div&gt;
#                      Predicted
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_e5a5cd9d51556b87e1b3888d90bee55e = L.circ

# %%
def mapmake2(history, prediction):
    m = folium.Map(location=[center_lat, center_lon], zoom_start=8)

    # History points
    history_coords = [(row[0], row[1]) for row in history]

    # Draw history track
    folium.PolyLine(
        history_coords,
        weight=3,
        tooltip="History"
    ).add_to(m)

    # Add last point marker
    folium.Marker(
        location=list(history_coords[-1]),
        popup="Last ping",
        tooltip="Last ping"
    ).add_to(m)

    # Add markers for history
    for i, (lat, lon) in enumerate(history_coords):
        folium.CircleMarker(
            location=[lat, lon],
            radius=3,
            popup=f"History {i}",
            fill=True
        ).add_to(m)

    # Add marker for predicted point
    folium.Marker(
        location=[prediction[0], prediction[1]],
        popup="Predicted point",
        tooltip="Predicted point"
    ).add_to(m)

    return m

# %%
history_4 = X_test[:, 0, :2].cpu().numpy()
predict = pred[0, 0, :]
mapmake2(history_4, predict)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c596eb2b6f59bbc9798525fafd4a2db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c596eb2b6f59bbc9798525fafd4a2db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c596eb2b6f59bbc9798525fafd4a2db = L.map(
#                 &quot;map_8c596eb2b6f59bbc9798525fafd4a2db&quot;,
#                 {
#                     center: [21.938385009765625, -77.26986694335938],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb7c687b7c681f7fd270ec42bf8aa4c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb7c687b7c681f7fd270ec42bf8aa4c6.addTo(map_8c596eb2b6f59bbc9798525fafd4a2db);
#
#
#             var poly_line_acba788fcd0404a7857e15841ca83509 = L.polyline(
#                 [[21.938385009765625, -77.26986694335938], [21.933635711669922, -77.26460266113281], [21.91769027709961, -77.24693298339844], [21.897485733032227, -77.22404479980469], [21.87637710571289, -77.20001220703125], [21.859695434570312, -77.1808853149414], [21.832847595214844, -77.15045928955078], [22.248676300048828, -77.55010223388672], [22.29853057861328, -77.60879516601562], [22.351890563964844, -77.68450927734375], [22.37944221496582, -77.7303695678711], [22.40825080871582, -77.7779312133789], [22.422971725463867, -77.80221557617188], [22.509387969970703, -77.9432144165039], [22.521249771118164, -77.96253967285156], [22.533523559570312, -77.98270416259766], [22.545068740844727, -78.00159454345703], [22.55115509033203, -78.01141357421875], [23.014495849609375, -79.27204132080078], [23.01920509338379, -79.28423309326172]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8c596eb2b6f59bbc9798525fafd4a2db);
#
#
#             poly_line_acba788fcd0404a7857e15841ca83509.bindTooltip(
#                 `&lt;div&gt;
#                      History
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ac589f0f7b812a7d0df9b8da1c5edaac = L.marker(
#                 [23.01920509338379, -79.28423309326172],
#                 {
# }
#             ).addTo(map_8c596eb2b6f59bbc9798525fafd4a2db);
#
#
#         var popup_40616ed1284aedec4845a05e82a39ca8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06726d22fdeb660602f57a9d0b5212e1 = $(`&lt;div id=&quot;html_06726d22fdeb660602f57a9d0b5212e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Last ping&lt;/div&gt;`)[0];
#                 popup_40616ed1284aedec4845a05e82a39ca8.setContent(html_06726d22fdeb660602f57a9d0b5212e1);
#
#
#
#         marker_ac589f0f7b812a7d0df9b8da1c5edaac.bindPopup(popup_40616ed1284aedec4845a05e82a39ca8)
#         ;
#
#
#
#
#             marker_ac589f0f7b812a7d0df9b8da1c5edaac.bindTooltip(
#                 `&lt;div&gt;
#                      Last ping
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_bf435d01eb523bedc99d1c6806dd5e59 = L.circleMarker(
#                 [21.938385009765625, -77.26986694335938],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_8c596eb2b6f59bbc9798525fafd4a2db);
#
#
#         var popup_799eca9a51ad488ea267e8ae8acf2056 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8f5f2f2f35037336b070f1ad51bdef6 = $(`&lt;div id=&quot;html_e8f5f2f2f35037336b070f1ad51bdef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;History 0&lt;/div&gt;`)[0];
#                 popup_799eca9a51ad488ea267e8ae8acf2056
